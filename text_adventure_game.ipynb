# %%
import time
import random

def start():
    """
    Escape Hult. Is a survival adventure text game set on Hult campus. 
    As the protagonist, you will attempt to escape Hult center as you are being hunted by 'IT'.
    This funtion starts the game.
    
    The game has 3 levels:
    1. The Classroom: The player must choose the right door before they can escape the classroom.
       The player has 3 attempts.
    2. The Elevator: The player must guess the correct number between 1 and 5 to complete the pass code, 
       before they can access the elevator 
    3. Lobby: The player must make the correct choice to complete this level and finish the game.
     
    BUGS
    1. When you restart the game after completion, you are taken back to the loop on Level 2.
       You never really exit that loop, even though there is a break statement. I suspect the break statment
       isn't applicable because it is called inside of a try-except block.
    """

    print("""
...it is 9:52pm, November 10th in classroom F. Less than 12 hours to the Python Data Science exams.
You've been studying with your friends for the whole day.

Your head feels heavy and you decide to take a nap.
You set your alarm for 15 minutes and ask your friends to wake you up, if the alarm doesn't. 

...

beep-beep.. beep-beep...

You open your eyes and look around. The class is empty! You look at the time and it is 3:25am!

YOU HEAR MOVEMENT AND A GROWLING SOUND COMING FROM THE CEILING!!!

...
""")
    
    # Start level one
    time.sleep(1)
    level_1()
    
def end():
    """
    This funtion is called right before the player quites the game
    """
    print("\n\n***Exiting Game***")

def win():
    """
    This function is called when a player succesfully completes the game. 
    A player can restart or quit the game.
    """
    
    print("""\n\n...\n\n
You run as fast as can! But IT cateches up with you!
Just as it is about to rip you to pieces, the glass by the entrance shatters!!!
A tactical team zip lines into the lobby and blows IT off with an RPG.

The leader takes off his helmet and you're shocked!

You yell out "Prof. Kusterert?"

...

"Hey wake up. your 15mins nap time is up. It's 10:15pm!"

You open your eyes and realize it was all a dream.

...

You're safe. You Win!!!
    """)
    running = True
    # This loop stays active, until user enters a valid choice to continue or end the game.
    while running:
        # Define player options
        options = [
            "1. Restart game",
            "2. Quit"
        ]
        
        print("\nWhat would you like to do")
        
        # Loop through and print options
        for option in options:
            print(option)
            time.sleep(1)
            
        # Convert list to lower case for easier comparison
        options = list_to_lower(options)
        
        # Get user response and convert to lower case for easier comparison
        choice = input(prompt=">")
        choice = choice.lower()

        # Check the option the user chose and branch the game accordingly
        if choice in options[0] or choice == "one":
            running = False
            welcome()
        elif choice in options[1] or choice == "two":
            running = False
            end()
        else:
            print("\nInvalid entry")

def lose(current_level):
    """
    This function is called whenver a player loses the game. 
    A player can replay the level, retstart the game or quit the game.
    You must pass the current level as an arguement whenever you call this function
    """
    
    print_separator()
    print("YOU DIED.")
    print_separator()
    
    # This loop stays active, until user enters a valid choice to continue or end the game.
    while True:
        # Define player options
        options = [
            "1. Replay this level",
            "2. Restart game",
            "3. Quit Game"
        ]
        
        print("\nWhat would you like to do")
        
        # Loop through and print options
        for option in options:
            print(option)
            time.sleep(1)

        # Convert list to lower case for easier comparison
        options = list_to_lower(options)
        
        # Get user response and convert to lower case for easier comparison
        choice = input(prompt=">")
        choice = choice.lower()

        # Check the option the user chose and branch the game accordingly
        if choice in options[0] or choice == "one":
            current_level()
            break
        elif choice in options[1] or choice == "two":
            start()
            break
        elif choice in options[2] or choice == "three":
            end()
            break
        else:
            print("\nInvalid entry")
    
    
def list_to_lower(list_items):
    """Converts any given list to lower case and returns it"""
    # Set empty list
    lower_case_list = []
    
    # Loop through given list and append lower case elememts to new list
    for list_item in list_items:
        lower_case_list.append(list_item.lower())
        
    # Return lower case list
    return lower_case_list


def shuffle_list(list_items):
    """Shuffles any given list and returns it"""
    # Set empty list
    shuffled_list = []
    
    # Set index variable
    index = 1
    
    # Shuffle list
    random.shuffle(list_items)
    
    # Loop through given list, concatenate index and append to new list
    for list_item in list_items:
        shuffled_list.append(f"{index}. {list_item}")
        index+=1
        
    # Return shuffled list
    return shuffled_list


def print_separator():
    """Mutiply a string by integer to avoid repitition"""
    
    # multiply and print the '*' chatracter
    print(f"\n{'*'*50}\n")
    
    
# Define Game levels
def level_1():
    """
    This function is for the first level of the game game. 
    The player is expected to choose the right door to successfully complete the level.
    The player has 2 tries, before they fail.
    """
    print("""\nYou know know you have less than 30 seconnds to leave the room.
There are two doors. One to the left, and one to the right.

    """)
    
    time_left = 30
        
    # This loop stays active for 3 attempts, until user enters a valid choice or loses the game.
    while time_left > 0:
        # Define player options
        options = [
            "Left",
            "Right"
        ]
        
        #Increment tries
        time_left-=10
        
        print("Which door will you take?")
        
        # Shuffle list
        options = shuffle_list(options)
        
        # Loop through and print options
        for option in options:
            print(option)
            time.sleep(1)
        
        # Convert list to lower case for easier comparison
        options = list_to_lower(options)
        
        # Get user response and convert to lower case for easier comparison
        choice = input(prompt=">")
        choice = choice.lower()

        # Check the option the user chose and branch the game accordingly
        if choice in options[0] or choice == "one":
            print(f"\nThe door is locked! You run back to the center of the class. You have {time_left}s left")
            
            if(time_left <= 0):
                print("\nThe ceiling rips apart and IT pounces on you.")
                lose(current_level = level_1)
                break
        elif choice in options[1] or choice == "two":
            level_2()
            break
        else:
            print(f"\nInvalid entry. You have {time}s left")
            if(time_left <= 0):
                print("\nThe ceiling rips apart and IT pounces on you.")
                lose(current_level = level_1)
                break
        
def level_2():
    """
    This function is for the second level of the game. 
    The player is expected to choose the right door to successfully complete the level.
    The player has 2 tries, before they fail.
    """

    print("""\n...\n\nYou make a run for the elevator\n\n...\n\n
You get to the elevator, but you require a 4 digit pin to access it.
There is a hint that the last number is between 1 and 5.
If you enter the wrong code 3 times, the system security will auto de-activate the elevator
Luckily, someone entered the first 3 numbers. All you have to do is guess the last number!.

    """)
    
    tries = 0
    
    # Define elevator code
    elevator_code = random.randint(1,5)
        
    # This loop stays active, until user enters a valid choice to continue or end the game.
    while tries < 3:
        #Increment tries
        tries+=1
        
        print("What is the last number?")
        choice = input(prompt=">")
        try:
            choice = int(choice)
            
            # Check the option the user chose and branch the game accordingly
            if choice == elevator_code:
                # Set exit condition for while loop
                tries = 3
                
                print("""\nBeeeeep...\"ACCESS GRANTED\"\n\nYou Press \"G\" to go to the ground floor\n\n... """)
                
                # Load level 3
                level_3()
            else:
                if choice > elevator_code:
                    print(f"""
    \nBeep...Beep... Incorrect. Warning you have {3-tries} tries left.\nTry a smaller number.""")
                else:
                    print(f"""
    \nBeep...Beep... Incorrect. Warning you have {3-tries} tries left.\nTry a bigger number""")

                if(tries > 2):
                    print("\nThe ceiling rips apart and IT pounces on you.")
                    lose(current_level = level_2)
        except:
            print(f"\nInvalid entry. Enter a number between 1 and 5. Warning you have {3-tries} tries left.")
            if(tries > 2):
                print("\nThe ceiling rips apart and IT pounces on you.")
                lose(current_level = level_2)
    
def level_3():
    """
    This function is for the third level of the game. 
    The player is expected to choose the right door to successfully complete the level.
    The player has 1 attempt, before they fail.
    """
    
    # Define player options
    options = [
        "1. Run towards the exit",
        "2. Find a weapon, stand your ground and fight",
        "3. Do nothing and hope for a miracle"
    ]
    
    # Prompt user to make level decision
    print("""\nAs you exit the elevator and run into the lobby. The elevator door bursts open. 
IT emerges and chases you.""")
    time.sleep(1)
    print("What will you do?")
    time.sleep(1)
    
    # Loop through and print options
    for option in options:
        print(option)
        time.sleep(1)

    # Convert list to lower case for easier comparison
    options = list_to_lower(options)

    # Get user response and convert to lower case for easier comparison
    choice = input(prompt=">")
    choice = choice.lower()

    # Check the option the user chose and branch the game accordingly
    if choice in options[0] or choice == "one":
        win()
    elif choice in options[1] or choice == "two":
        print("\nIT charges towards you and rips off your head with one swipe.\n")
        lose(current_level = level_3)
    elif choice in options[2] or choice == "three":
        print("\nYou close your eyes and say your prayers. The last thing you hear are IT's footsteps.\n")
        lose(current_level = level_3)
    else:
        print("\nInvalid entry - For not following instructions, it rips you into a thousand pieces.")
        lose(current_level = level_3)
    
# Start the game
start()
# Out:
# ...it is 9:52pm, November 10th in classroom F. Less than 12 hours to the Python Data Science exams.
# You've been studying with your friends for the whole day.
#
# Your head feels heavy and you decide to take a nap.
# You set your alarm for 15 minutes and ask your friends to wake you up, if the alarm doesn't.
#
# ...
#
# beep-beep.. beep-beep...
#
# You open your eyes and look around. The class is empty! You look at the time and it is 3:25am!
#
# YOU HEAR MOVEMENT AND A GROWLING SOUND COMING FROM THE CEILING!!!
#
# ...
#
#
# You know know you have less than 30 seconnds to leave the room.
# There are two doors. One to the left, and one to the right.
#
#
# Which door will you take?
# 1. Left
# 2. Right
# >r
#
# ...
#
# You make a run for the elevator
#
# ...
#
#
# You get to the elevator, but you require a 4 digit pin to access it.
# There is a hint that the last number is between 1 and 5.
# If you enter the wrong code 3 times, the system security will auto de-activate the elevator
# ...
